# %% [markdown]
# # vgg19

# %% [markdown]
# ### Imports

# %%
# Добавляем текущую директорию в путь
import os
import sys
sys.path.append(os.path.abspath('..'))

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import models, datasets
from pathlib import Path
import logging
import polars as pl
import matplotlib.pyplot as plt
import numpy as np
from src.models import load_model, confusion_matrix, Trainer
from src.data import load_datasets, create_dataloaders
from src.utils import utils

# %matplotlib inline

# %%
DIR = Path.cwd().parent

# %% [markdown]
# ### Logging

# %%
# Настройка логгера
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %% [markdown]
# ### Loading the configuration for the dataset

# %%
path_config_data = Path("../configs/data.yaml").absolute()
config_data = utils.load_config(path_config_data)

# %%
# Путь хранения датасета
path_data_load = Path(DIR, config_data["root_dir"])
train_dataset, val_dataset = load_datasets(path_data_load, config_data["image_size"])

# %%
# Создаем DataLoader
train_loader, val_loader = create_dataloaders(
        train_dataset,
        val_dataset,
        config_data['batch_size'],
        config_data['num_workers'])

# %% [markdown]
# ### Loading the configuration for the model

# %%
path_config_model = Path("../configs/transfer_learning_vgg19.yaml").absolute()
config_dict = utils.load_config(path_config_model)
config_model = config_dict['model']

# %%
# Фиксируем random seed для воспроизводимости
utils.set_seed(config_model['seed'])

# %%
# Определение устройства
device_obj = torch.device(
    config_model['device'] if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device_obj}")
# Out:
# Using device: cuda

# %% [markdown]
# ### Model VGG19

# %%
# VGG19 с заморозкой всех сверточных слоев
model = load_model(config_model['name'], config_model['num_classes'])
model = model.to(device_obj)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to C:\Users\RoyalPC/.cache\torch\hub\checkpoints\vgg19-dcbb9e9d.pth
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 548M/548M [00:51<00:00, 11.1MB/s]

# %%
model.classifier
# Out:
# Sequential(
#   (0): Linear(in_features=25088, out_features=4096, bias=True)
#   (1): ReLU(inplace=True)
#   (2): Dropout(p=0.5, inplace=False)
#   (3): Linear(in_features=4096, out_features=4096, bias=True)
#   (4): ReLU(inplace=True)
#   (5): Dropout(p=0.5, inplace=False)
#   (6): Linear(in_features=4096, out_features=37, bias=True)
# )

# %% [markdown]
# ### Optimizer

# %%
# Оптимизатор и scheduler
optimizer = torch.optim.Adam(
    model.parameters(),
    lr=config_model['lr'],
    weight_decay=config_model['weight_decay'],
)

# %%
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, eta_min=1e-5, T_max=30)

# %% [markdown]
# ### Train model

# %%
# Создание тренера
trainer = Trainer(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    optimizer=optimizer,
    scheduler=scheduler,
    device=device_obj,
    output_dir=Path(DIR, config_model['output_dir']),
    logger=logger,
)

# %% [markdown]
# ### Epochs

# %%
# Устанавливаем начальную эпоку если ранее было обучение модель продолжит
# с того места на котором остановилось обучение
start_epoch:int = 0
checkpoint_path = Path(DIR, config_dict['resume'])
if config_dict.get('resume') and checkpoint_path.exists():
    checkpoint = trainer.load_checkpoint(checkpoint_path)
    start_epoch = checkpoint.get('epoch', 0) + 1
    print(f"Resumed from epoch {start_epoch}")

# %%
best_metric = trainer.train(
    num_epochs=config_model['epochs'],
    start_epoch=start_epoch,
)
# Out:
# Epoch 0 [train]: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 115/115 [00:22<00:00,  5.20it/s, loss=2.92, acc=12.9]
# INFO:__main__:Epoch 0: Train accuracy: 0.1293
# Validating: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 115/115 [00:16<00:00,  6.81it/s]
# INFO:__main__:Epoch 0: Val loss: 1.7030, Val accuracy: 0.3865
# INFO:__main__:New best model saved with metric: 0.3865
# Epoch 1 [train]: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 115/115 [00:21<00:00,  5.26it/s, loss=1.68, acc=42.4]
# INFO:__main__:Epoch 1: Train accuracy: 0.4239
# Validating: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 115/115 [00:16<00:00,  6.84it/s]
# INFO:__main__:Epoch 1: Val loss: 0.9582, Val accuracy: 0.6599
# INFO:__main__:New best model saved with metric: 0.6599
# Epoch 2 [train]: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 115/115 [00:21<00:00,  5.30it/s, loss=1.22, acc=58.9]
# INFO:__main__:Epoch 2: Train accuracy: 0.5894
# Validating: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 115/115 [00:16<00:00,  6.85it/s]
# INFO:__main__:Epoch 2: Val loss: 0.6699, Val accuracy: 0.7664
# INFO:__main__:New best model saved with metric: 0.7664
# Epoch 3 [train]: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 115/115 [00:21<00:00,  5.28it/s, loss=0.92, acc=70.5]
# INFO:__main__:Epoch 3: Train accuracy: 0.7049
# Validating: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 115/115 [00:16<00:00,  6
[train]: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 115/115 [00:21<00:00,  5.30it/s, loss=0.441, acc=86.2]
# INFO:__main__:Epoch 18: Train accuracy: 0.8617
# Validating: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 115/115 [00:16<00:00,  6.79it/s]
# INFO:__main__:Epoch 18: Val loss: 0.3446, Val accuracy: 0.8902
# Epoch 19 [train]: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 115/115 [00:21<00:00,  5.27it/s, loss=0.459, acc=85.2]
# INFO:__main__:Epoch 19: Train accuracy: 0.8516
# Validating: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 115/115 [00:16<00:00,  6.85it/s]
# INFO:__main__:Epoch 19: Val loss: 0.3293, Val accuracy: 0.8948
# INFO:__main__:New best model saved with metric: 0.8948
# Epoch 20 [train]: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 115/115 [00:21<00:00,  5.30it/s, loss=0.428, acc=86.4]
# INFO:__main__:Epoch 20: Train accuracy: 0.8636
# Validating: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 115/115 [00:16<00:00,  6.80it/s]
# INFO:__main__:Epoch 20: Val loss: 0.3249, Val accuracy: 0.8929
# Epoch 21 [train]: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 115/115 [00:21<00:00,  5.27it/s, loss=0.447, acc=86.2]
# INFO:__main__:Epoch 21: Train accuracy: 0.8625
# Validating: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 115/115 [00:16<00:00,  6.84it/s]
# INFO:__main__:Epoch 21: Val loss: 0.3295, Val accuracy: 0.8883
# Epoch 22 [train]: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 115/115 [00:21<00:00,  5.32it/s, loss=0.418, acc=86.9]
# INFO:__main__:Epoch 22: Train accuracy: 0.8693
# Validating: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 115/115 [00:16<00:00,  6.88it/s]
# INFO:__main__:Epoch 22: Val loss: 0.3181, Val accuracy: 0.8983
# INFO:__main__:New best model saved with metric: 0.8983
# Epoch 23 [train]: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 115/115 [00:21<00:00,  5.29it/s, loss=0.427, acc=86.1]
# INFO:__main__:Epoch 23: Train accuracy: 0.8611
# Validating: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 115/115 [00:16<00:00,  6.78it/s]
# INFO:__main__:Epoch 23: Val loss: 0.3017, Val accuracy: 0.8989
# INFO:__main__:New best model saved with metric: 0.8989
# Epoch 24 [train]: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 115/115 [00:21<00:00,  5.31it/s, loss=0.424, acc=86.5]
# INFO:__main__:Epoch 24: Train accuracy: 0.8647
# Validating: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 115/115 [00:16<00:00,  6.90it/s]
# INFO:__main__:Epoch 24: Val loss: 0.3134, Val accuracy: 0.8992
# INFO:__main__:New best model saved with metric: 0.8992
# Epoch 25 [train]: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 115/115 [00:21<00:00,  5.30it/s, loss=0.405, acc=86.3]
# INFO:__main__:Epoch 25: Train accuracy: 0.8628
# Validating: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 115/115 [00:16<00:00,  6.84it/s]
# INFO:__main__:Epoch 25: Val loss: 0.3162, Val accuracy: 0.8929
# Epoch 26 [train]: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 115/115 [00:21<00:00,  5.31it/s, loss=0.426, acc=86.6]
# INFO:__main__:Epoch 26: Train accuracy: 0.8658
# Validating: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 115/115 [00:16<00:00,  6.88it/s]
# INFO:__main__:Epoch 26: Val loss: 0.3069, Val accuracy: 0.8994
# INFO:__main__:New best model saved with metric: 0.8994
# Epoch 27 [train]: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 115/115 [00:21<00:00,  5.26it/s, loss=0.386, acc=87.6]
# INFO:__main__:Epoch 27: Train accuracy: 0.8761
# Validating: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 115/115 [00:16<00:00,  6.84it/s]
# INFO:__main__:Epoch 27: Val loss: 0.3035, Val accuracy: 0.9030
# INFO:__main__:New best model saved with metric: 0.9030
# Epoch 28 [train]: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 115/115 [00:21<00:00,  5.27it/s, loss=0.389, acc=87.3]
# INFO:__main__:Epoch 28: Train accuracy: 0.8731
# Validating: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 115/115 [00:16<00:00,  6.81it/s]
# INFO:__main__:Epoch 28: Val loss: 0.3181, Val accuracy: 0.8953
# Epoch 29 [train]: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 115/115 [00:21<00:00,  5.32it/s, loss=0.388, acc=87.9]
# INFO:__main__:Epoch 29: Train accuracy: 0.8791
# Validating: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 115/115 [00:16<00:00,  6.81it/s]
# INFO:__main__:Epoch 29: Val loss: 0.3090, Val accuracy: 0.8983

# %%
best_metric
# Out:
# 0.9029708367402562

# %% [markdown]
# ### best model checkpoint

# %%
best_model_checkpoint = trainer.load_checkpoint(Path(DIR, "./data/models/exp_vgg19_transfer/best_model.pth"))

# %% [markdown]
# ### Confusion matrix

# %%
confusion_matrix(trainer.model, val_loader, config_model['device'], config_model['num_classes'], val_dataset.classes)

# %% [markdown]
# Моедль часто путает класс American Pit Bull Terrier с классом Staffordshire Bull Terrier.
# Собаки похожи друг на друга  и имеют минимальные отличия.
# Кошки - Egiptian Mau путает с Bengal.

# %% [markdown]
# ### Resume

# %% [markdown]
# Моедль показала результат в 90%.
